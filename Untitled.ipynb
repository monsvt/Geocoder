# %%
import pandas
from geopy.geocoders import ArcGIS

# %%
df=pandas.read_csv("supermarkets.csv")

# %%
df["address"]=df["Address"]+", "+df["City"]+", "+df["State"]
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                       address
# 0          8         3666 21st St, San Francisco, CA 94114
# 1         15       735 Dolores St, San Francisco, CA 94119
# 2         25  332 Hill St, San Francisco, California 94114
# 3         10         3995 23rd St, San Francisco, CA 94114
# 4         12    1056 Sanchez St, San Francisco, California
# 5         20      551 Alvarado St, San Francisco, CA 94114

# %%
nom=ArcGIS()
df["Coordinates"]=df["Address"].apply(nom.geocode)
#df.Coordinates[0][1]
#df.Coordinates
#df["Latitude"]=df["Coordinates"][0][1][0]
#df["Longitude"]=df["Coordinates"][0][1][1]
df["Latitude"]=df["Coordinates"].apply(lambda x:x.latitude if x != None else None)
df["Longitude"]=df["Coordinates"].apply(lambda x:x.longitude if x != None else None)
#df.Coordinates[0].latitude
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                       address  \
# 0          8         3666 21st St, San Francisco, CA 94114
# 1         15       735 Dolores St, San Francisco, CA 94119
# 2         25  332 Hill St, San Francisco, California 94114
# 3         10         3995 23rd St, San Francisco, CA 94114
# 4         12    1056 Sanchez St, San Francisco, California
# 5         20      551 Alvarado St, San Francisco, CA 94114
#
# ...

# %%
if df.Address.all != None:
    print("Hello")
else:
    df.rename(columns={'address':'Address'})
    
df
# Out:
# Hello
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                       address  \
# 0          8         3666 21st St, San Francisco, CA 94114
# 1         15       735 Dolores St, San Francisco, CA 94119
# 2         25  332 Hill St, San Francisco, California 94114
# 3         10         3995 23rd St, San Francisco, CA 94114
# 4         12    1056 Sanchez St, San Francisco, California
# 5         20      551 Alvarado St, San Francisco, CA 94114
#
# ...

# %%
df.drop(columns="Employees", inplace=True)
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                                         address   Latitude   Longitude
# 0         3666 21st St, San Francisco, CA 94114  41.609561   -8.736949
# 1       735 Dolores St, San Francisco, CA 94119  37.654810 -109.041964
# 2  332 Hill St, San Francisco, California 94114  53.883330   -8.083330
# 3         3995 23rd St, San Francisco, CA 94114 -38.599070  145.596040
# 4    1056 Sanchez St, San Francisco, California  19.230730  -69.612950
# ...

# %%
import pandas
from geopy.geocoders import ArcGIS
df1=pandas.DataFrame([[1,2,2],["Hello","23","bye"]],columns=["Address","vibe","greet"])
df1
# Out:
#   Address vibe greet
# 0       1    2     2
# 1   Hello   23   bye

# %%
try:
    if df1.address.all:
        df1.rename(columns={'address':'Address'},inplace=True)
except:
    pass

df1
# Out:
#   Address vibe greet
# 0       1    2     2
# 1   Hello   23   bye

# %%
df1.drop("vibe",1)
# Out:
#   Address greet
# 0       1     2
# 1   Hello   bye
